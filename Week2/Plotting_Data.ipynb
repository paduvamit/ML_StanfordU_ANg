% %%
ls
% Out:
% Computing_On_Data.ipynb   Plotting_Data.ipynb  priceY.dat
% Moving_Data_Around.ipynb  featuresX.dat

% %%
t = [0:0.01:0.98]
% Out:
% t =
%
%  Columns 1 through 7:
%
%    0.00000   0.01000   0.02000   0.03000   0.04000   0.05000   0.06000
%
%  Columns 8 through 14:
%
%    0.07000   0.08000   0.09000   0.10000   0.11000   0.12000   0.13000
%
%  Columns 15 through 21:
%
%    0.14000   0.15000   0.16000   0.17000   0.18000   0.19000   0.20000
%
%  Columns 22 through 28:
%
%    0.21000   0.22000   0.23000   0.24000   0.25000   0.26000   0.27000
%
%  Columns 29 through 35:
%
%    0.28000   0.29000   0.30000   0.31000   0.32000   0.33000   0.34000
%
%  Columns 36 through 42:
%
%    0.35000   0.36000   0.37000   0.38000   0.39000   0.40000   0.41000
%
%  Columns 43 through 49:
%
%    0.42000   0.43000   0.44000   0.45000   0.46000   0.47000   0.48000
%
%  Columns 50 through 56:
%
%    0.49000   0.50000   0.51000   0.52000   0.53000   0.54000   0.55000
%
%  Columns 57 through 63:
%
%    0.56000   0.57000   0.58000   0.59000   0.60000   0.61000   0.62000
%
%  Columns 64 through 70:
%
%    0.63000   0.64000   0.65000   0.66000   0.67000   0.68000   0.69000
%
%  Columns 71 through 77:
%
%    0.70000   0.71000   0.72000   0.73000   0.74000   0.75000   0.76000
%
%  Columns 78 through 84:
%
%    0.77000   0.78000   0.79000   0.80000   0.81000   0.82000   0.83000
%
%  Columns 85 through 91:
%
%    0.84000   0.85000   0.86000   0.87000   0.88000   0.89000   0.90000
%
%  Columns 92 through 98:
%
%    0.91000   0.92000   0.93000   0.94000   0.95000   0.96000   0.97000
%
%  Column 99:
%
%    0.98000

% %%
t = [0:0.01:0.98];

% %%
t
% Out:
% t =
%
%  Columns 1 through 7:
%
%    0.00000   0.01000   0.02000   0.03000   0.04000   0.05000   0.06000
%
%  Columns 8 through 14:
%
%    0.07000   0.08000   0.09000   0.10000   0.11000   0.12000   0.13000
%
%  Columns 15 through 21:
%
%    0.14000   0.15000   0.16000   0.17000   0.18000   0.19000   0.20000
%
%  Columns 22 through 28:
%
%    0.21000   0.22000   0.23000   0.24000   0.25000   0.26000   0.27000
%
%  Columns 29 through 35:
%
%    0.28000   0.29000   0.30000   0.31000   0.32000   0.33000   0.34000
%
%  Columns 36 through 42:
%
%    0.35000   0.36000   0.37000   0.38000   0.39000   0.40000   0.41000
%
%  Columns 43 through 49:
%
%    0.42000   0.43000   0.44000   0.45000   0.46000   0.47000   0.48000
%
%  Columns 50 through 56:
%
%    0.49000   0.50000   0.51000   0.52000   0.53000   0.54000   0.55000
%
%  Columns 57 through 63:
%
%    0.56000   0.57000   0.58000   0.59000   0.60000   0.61000   0.62000
%
%  Columns 64 through 70:
%
%    0.63000   0.64000   0.65000   0.66000   0.67000   0.68000   0.69000
%
%  Columns 71 through 77:
%
%    0.70000   0.71000   0.72000   0.73000   0.74000   0.75000   0.76000
%
%  Columns 78 through 84:
%
%    0.77000   0.78000   0.79000   0.80000   0.81000   0.82000   0.83000
%
%  Columns 85 through 91:
%
%    0.84000   0.85000   0.86000   0.87000   0.88000   0.89000   0.90000
%
%  Columns 92 through 98:
%
%    0.91000   0.92000   0.93000   0.94000   0.95000   0.96000   0.97000
%
%  Column 99:
%
%    0.98000

% %%
y1 = sin(2*pi*4*t)
% Out:
% y1 =
%
%  Columns 1 through 7:
%
%    0.00000   0.24869   0.48175   0.68455   0.84433   0.95106   0.99803
%
%  Columns 8 through 14:
%
%    0.98229   0.90483   0.77051   0.58779   0.36812   0.12533  -0.12533
%
%  Columns 15 through 21:
%
%   -0.36812  -0.58779  -0.77051  -0.90483  -0.98229  -0.99803  -0.95106
%
%  Columns 22 through 28:
%
%   -0.84433  -0.68455  -0.48175  -0.24869  -0.00000   0.24869   0.48175
%
%  Columns 29 through 35:
%
%    0.68455   0.84433   0.95106   0.99803   0.98229   0.90483   0.77051
%
%  Columns 36 through 42:
%
%    0.58779   0.36812   0.12533  -0.12533  -0.36812  -0.58779  -0.77051
%
%  Columns 43 through 49:
%
%   -0.90483  -0.98229  -0.99803  -0.95106  -0.84433  -0.68455  -0.48175
%
%  Columns 50 through 56:
%
%   -0.24869  -0.00000   0.24869   0.48175   0.68455   0.84433   0.95106
%
%  Columns 57 through 63:
%
%    0.99803   0.98229   0.90483   0.77051   0.58779   0.36812   0.12533
%
%  Columns 64 through 70:
%
%   -0.12533  -0.36812  -0.58779  -0.77051  -0.90483  -0.98229  -0.99803
%
%  Columns 71 through 77:
%
%   -0.95106  -0.84433  -0.68455  -0.48175  -0.24869  -0.00000   0.24869
%
%  Columns 78 through 84:
%
%    0.48175   0.68455   0.84433   0.95106   0.99803   0.98229   0.90483
%
%  Columns 85 through 91:
%
%    0.77051   0.58779   0.36812   0.12533  -0.12533  -0.36812  -0.58779
%
%  Columns 92 through 98:
%
%   -0.77051  -0.90483  -0.98229  -0.99803  -0.95106  -0.84433  -0.68455
%
%  Column 99:
%
%   -0.48175

% %%
y1;

% %%
plot(t,y1);

% %%
y2 = (cos(2*pi*4*t));

% %%
plot(t,y2);

% %%
hold on;

% %%
plot(t,y2);

% %%
plot(t,y1);

% %%
hold on;

% %%
plot(t,y2,'r');

% %%
plot(t,y1)

% %%
plot(t,y1);
hold on;
plot(t,y2,'g');
xlabel('time');
ylabel('value');
legend('sin','cos')
title('my plot')
print -dpng 'myPlot.png'

% %%
figure(1); plot(t,y1);
figure(2); plot(t,y2);

% %%
subplot(1,2,1); %DIvides plot into 1x2 grid,access first element
plot(t,y1);
axis([0.5 1 -1 1])
subplot(1,2,2);
plot(t,y2,'r');
axis([0.5 1 -1 1])

% %%
A = magic(5)
% Out:
% A =
%
%    17   24    1    8   15
%    23    5    7   14   16
%     4    6   13   20   22
%    10   12   19   21    3
%    11   18   25    2    9

% %%
imagesc(A)

% %%
disp(A);
imagesc(A),colorbar,colormap gray;
% Out:
%    17   24    1    8   15
%    23    5    7   14   16
%     4    6   13   20   22
%    10   12   19   21    3
%    11   18   25    2    9

% %%
imagesc(magic(15)),colorbar,colormap gray;
